# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Dataset/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
sns.pairplot(df,hue='Survived')

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sns.boxplot(x='Pclass',y='Age',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
def impute_age(cols):
    pclass=cols[0]
    age=cols[1]

    if pclass==1:
        return 42
    elif pclass==2:
        return 25
    else:
        return 23

# %%
df['Age']=df[['Pclass','Age']].apply(impute_age,axis=1)
# Out:
# C:\Users\karakkir\AppData\Local\Temp\ipykernel_24616\2391140620.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pclass=cols[0]
# C:\Users\karakkir\AppData\Local\Temp\ipykernel_24616\2391140620.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age=cols[1]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex  Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male   23      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female   23      1      0
# 2                     Myles, Mr. Thomas Francis    male   25      0      0
# 3                              Wirz, Mr. Albert    male   23      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   23      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex  Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male   23      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female   23      1      0
# 2                     Myles, Mr. Thomas Francis    male   25      0      0
# 3                              Wirz, Mr. Albert    male   23      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   23      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dropna(inplace=True)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Survived     417 non-null    int64
#  2   Pclass       417 non-null    int64
#  3   Name         417 non-null    object
#  4   Sex          417 non-null    object
#  5   Age          417 non-null    int64
#  6   SibSp        417 non-null    int64
#  7   Parch        417 non-null    int64
#  8   Ticket       417 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     417 non-null    object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 39.1+ KB

# %% [markdown]
# Converting Categorical features

# %%
Sex=pd.get_dummies(df['Sex'],drop_first=True)
embark=pd.get_dummies(df['Embarked'],drop_first=True)

# %%
df.drop(['Name','Sex','Ticket','Embarked'],axis=1,inplace=True)

# %%
df=pd.concat([df,Sex,embark],axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare   male      Q  \
# 0          892         0       3   23      0      0   7.8292   True   True
# 1          893         1       3   23      1      0   7.0000  False  False
# 2          894         0       2   25      0      0   9.6875   True   True
# 3          895         0       3   23      0      0   8.6625   True  False
# 4          896         1       3   23      1      1  12.2875  False  False
#
#        S
# 0  False
# 1   True
# 2  False
# 3   True
# 4   True
